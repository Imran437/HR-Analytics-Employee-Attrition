# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
df = pd.read_csv("C:/Work/Projects/Project Python/HR-Employee-Attrition.csv")

# %%
# create a copy of the dataset
df_clean = df.copy()

# %%
# Basic Inspection
# check the first 5 rows of the data
df_clean.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Check the last 5 rows of the data
df_clean.tail(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df_clean.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 241    32        No         Non-Travel        976                   Sales
# 1176   49        No      Travel_Rarely        301  Research & Development
# 531    32        No      Travel_Rarely       1018  Research & Development
# 831    31       Yes  Travel_Frequently        874  Research & Development
# 817    36        No         Non-Travel        217  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 241                 26          4      Marketing              1
# 1176                22          4          Other              1
# 531                  3          2  Life Sciences              1
# 831                 15          3        Medical              1
# 817                 18          4  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
# check the shape of the data
df_clean.shape
# Out:
# (1470, 35)

# %%
# check columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# check datatypes of each column and non null count
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Data cleaning
# check missing values in the data
df_clean.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# check percentage of missing values
(df_clean.isnull().mean()*100).round(2)
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# ...

# %%
# check duplicate records in the data
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
# summary statistics of the numeric column
df_clean.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# summary statistics for categorical columns
df_clean.describe(include = "object")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
# check unique values in all object column 
categorical_cols = df_clean.select_dtypes(include = "object").columns

for col in categorical_cols:
    print(f"\n{col}") 
    print(df_clean[col].value_counts())
# Out:
# Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
# BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
# JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
# check for constant columns
for col in df_clean.columns:
    if df_clean[col].nunique() == 1:
        print(col)
# Out:
# EmployeeCount
# Over18
# StandardHours

# %%
# Check Outliers
numeric_cols = df_clean.select_dtypes(include = np.number).columns
numeric_cols
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Detect outliers using Boxplot method
for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    plt.boxplot(df_clean[col], vert=False)
    plt.title(col)
    plt.show()

# %%
# Detect outliers using IQR method
for col in numeric_cols:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df_clean[(df_clean[col] < lower) | (df_clean[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# Age: 0 outliers
# DailyRate: 0 outliers
# DistanceFromHome: 0 outliers
# Education: 0 outliers
# EmployeeCount: 0 outliers
# EmployeeNumber: 0 outliers
# EnvironmentSatisfaction: 0 outliers
# HourlyRate: 0 outliers
# JobInvolvement: 0 outliers
# JobLevel: 0 outliers
# JobSatisfaction: 0 outliers
# MonthlyIncome: 114 outliers
# MonthlyRate: 0 outliers
# NumCompaniesWorked: 52 outliers
# PercentSalaryHike: 0 outliers
# PerformanceRating: 226 outliers
# RelationshipSatisfaction: 0 outliers
# StandardHours: 0 outliers
# StockOptionLevel: 85 outliers
# TotalWorkingYears: 63 outliers
# TrainingTimesLastYear: 238 outliers
# WorkLifeBalance: 0 outliers
# YearsAtCompany: 104 outliers
# YearsInCurrentRole: 21 outliers
# YearsSinceLastPromotion: 107 outliers
# YearsWithCurrManager: 14 outliers

# %%
# Outlier Summary Table
outlier_summary = []

for col in numeric_cols:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    count = ((df_clean[col] < lower) | (df_clean[col] > upper)).sum()

    outlier_summary.append({
        "Column": col,
        "Outliers": count
    })


outlier_df = pd.DataFrame(outlier_summary)
outlier_df.sort_values("Outliers", ascending=False)
# Out:
#                       Column  Outliers
# 20     TrainingTimesLastYear       238
# 15         PerformanceRating       226
# 11             MonthlyIncome       114
# 24   YearsSinceLastPromotion       107
# 22            YearsAtCompany       104
# 18          StockOptionLevel        85
# 19         TotalWorkingYears        63
# 13        NumCompaniesWorked        52
# 23        YearsInCurrentRole        21
# 25      YearsWithCurrManager        14
# 10           JobSatisfaction         0
# 9                   JobLevel         0
# 12               MonthlyRate         0
# 1                  DailyRate         0
# 14         PercentSalaryHike         0
# 8             JobInvolvement         0
# 16  RelationshipSatisfaction         0
# 17             StandardHours         0
# 7                 HourlyRate         0
# 6    EnvironmentSatisfaction         0
# 5             EmployeeNumber         0
# 21           WorkLifeBalance         0
# 4              EmployeeCount         0
# ...

# %%
# Check Invalid values 
# Age column
print(df_clean["Age"].min())
print(df_clean["Age"].max())
# Monthly Income column
print(df_clean["MonthlyIncome"].min())
print(df_clean["MonthlyIncome"].max())

# Monthly Rate
print(df_clean["MonthlyRate"].min())
print(df_clean["MonthlyRate"].max())
# Out:
# 18
# 60
# 1009
# 19999
# 2094
# 26999

# %%
# Check data consistency
# YearsAtCompany should not exceed TotalWorkingYears at company
(df_clean["YearsAtCompany"] > df_clean["TotalWorkingYears"]).sum()
# Out:
# np.int64(0)

# %%
# MonthlyIncome should not be negative
(df_clean["MonthlyIncome"] < 0).sum()
# Out:
# np.int64(0)

# %%
# Age should be within a reasonable range
(df_clean["Age"] > 18) & (df_clean["Age"] < 60).sum()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1465    True
# 1466    True
# 1467    True
# 1468    True
# 1469    True
# Name: Age, Length: 1470, dtype: bool

# %%
# Rename columns for consistency
# convert camel case to snake case
import re
df_clean.columns = [
    re.sub(r'(?<!^)(?=[A-Z])','_', col).lower()
           for col in df_clean.columns
]

# %%
df_clean.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_count',
#        'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_income', 'monthly_rate',
#        'num_companies_worked', 'over18', 'over_time', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'standard_hours',
#        'stock_option_level', 'total_working_years', 'training_times_last_year',
#        'work_life_balance', 'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager'],
#       dtype='object')

# %%
# Remove unnecessary columns
df_clean = df_clean.drop(
    columns=["employee_count", "over18", "standard_hours"]
)

# %% [markdown]
# # Target Variable Analysis

# %%
# Attrition Count
df_clean["attrition"].value_counts()
# Out:
# attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# Attrition Percentage 
(df_clean["attrition"].value_counts(normalize = True) * 100).round(2)
# Out:
# attrition
# No     83.88
# Yes    16.12
# Name: proportion, dtype: float64

# %%
# Bar chart
df_clean["attrition"].value_counts().plot(kind = "bar")
plt.title("Employee Attrition")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# # Numerical Variable

# %%
# Summary Statistics
numeric_cols = df_clean.select_dtypes(include = np.number).columns
df_clean[numeric_cols].describe()
# Out:
#                age   daily_rate  distance_from_home    education  \
# count  1470.000000  1470.000000         1470.000000  1470.000000
# mean     36.923810   802.485714            9.192517     2.912925
# std       9.135373   403.509100            8.106864     1.024165
# min      18.000000   102.000000            1.000000     1.000000
# 25%      30.000000   465.000000            2.000000     2.000000
# 50%      36.000000   802.000000            7.000000     3.000000
# 75%      43.000000  1157.000000           14.000000     4.000000
# max      60.000000  1499.000000           29.000000     5.000000
#
#        employee_number  environment_satisfaction  hourly_rate  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.721769    65.891156
# std         602.024335                  1.093082    20.329428
# min           1.000000                  1.000000    30.000000
# 25%         491.250000                  2.000000    48.000000
# ...

# %%
# Histogram
df_clean[numeric_cols].hist(figsize=(15,12))
plt.tight_layout()
plt.show()

# %%
# Categorical variables
df_clean["department"].value_counts()
# Out:
# department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
# Visulization
df_clean["department"].value_counts().plot(kind = "bar")
plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Gender
df_clean["gender"].value_counts()
# Out:
# gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
# Visulization
df_clean["gender"].value_counts().plot(kind= "bar")
plt.title("Employees by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Job Role
df_clean["job_role"].value_counts()
# Out:
# job_role
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
# visulization
df_clean["job_role"].value_counts().plot(kind= "bar")
plt.title("Employees by Job Role")
plt.xlabel("Job Role")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Marital Status
df_clean["marital_status"].value_counts()
# Out:
# marital_status
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
# Visualization
df_clean["marital_status"].value_counts().plot(kind = "bar")
plt.title("Employee by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Education Field
df_clean["education_field"].value_counts()
# Out:
# education_field
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
# visualization
df_clean["education_field"].value_counts().plot(kind = "bar")
plt.title("Employees by Education Field")
plt.xlabel("Education Field")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Business Travel
df_clean["business_travel"].value_counts()
# Out:
# business_travel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
# visualization
df_clean["business_travel"].value_counts().plot(kind = "bar")
plt.title("Employees by Business Travel")
plt.xlabel("Business Travel")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Over Time
df_clean["over_time"].value_counts().plot(kind = "bar")
plt.title("Employees by Over Time")
plt.xlabel("Over Time")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# # Correlation

# %%
corr = df_clean.corr(numeric_only = True)
corr
# Out:
#                                  age  daily_rate  distance_from_home  \
# age                         1.000000    0.010661           -0.001686
# daily_rate                  0.010661    1.000000           -0.004985
# distance_from_home         -0.001686   -0.004985            1.000000
# education                   0.208034   -0.016806            0.021042
# employee_number            -0.010145   -0.050990            0.032916
# environment_satisfaction    0.010146    0.018355           -0.016075
# hourly_rate                 0.024287    0.023381            0.031131
# job_involvement             0.029820    0.046135            0.008783
# job_level                   0.509604    0.002966            0.005303
# job_satisfaction           -0.004892    0.030571           -0.003669
# monthly_income              0.497855    0.007707           -0.017014
# monthly_rate                0.028051   -0.032182            0.027473
# num_companies_worked        0.299635    0.038153           -0.029251
# ...

# %%
# Heatmap
plt.figure(figsize=(14,10))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Business Analysis

# %%
# Department vs Attrition
pd.crosstab(df_clean["department"], df_clean["attrition"])
# Out:
# attrition                No  Yes
# department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# Gender vs Attrition
pd.crosstab(df_clean["gender"], df_clean["attrition"])
# Out:
# attrition   No  Yes
# gender
# Female     501   87
# Male       732  150

# %%
# OverTime vs Attrition
pd.crosstab(df_clean["over_time"], df_clean["attrition"])
# Out:
# attrition   No  Yes
# over_time
# No         944  110
# Yes        289  127

# %%
# Job role vs Attrition
pd.crosstab(df_clean["job_role"], df_clean["attrition"])
# Out:
# attrition                   No  Yes
# job_role
# Healthcare Representative  122    9
# Human Resources             40   12
# Laboratory Technician      197   62
# Manager                     97    5
# Manufacturing Director     135   10
# Research Director           78    2
# Research Scientist         245   47
# Sales Executive            269   57
# Sales Representative        50   33

# %%
# add percentage in comparing categories
pd.crosstab(df_clean["department"], df_clean["attrition"], normalize="index")*100
# Out:
# attrition                      No        Yes
# department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
# for overtime
pd.crosstab(df_clean["over_time"], df_clean["attrition"], normalize= "index")* 100
# Out:
# attrition         No        Yes
# over_time
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %%
# job satisfaction vs attrition
pd.crosstab(df_clean["job_satisfaction"], df_clean["attrition"], normalize= "index") * 100
# Out:
# attrition                No        Yes
# job_satisfaction
# 1                 77.162630  22.837370
# 2                 83.571429  16.428571
# 3                 83.484163  16.515837
# 4                 88.671024  11.328976

# %%
# add totals
pd.crosstab(
    df_clean["department"],
    df_clean["attrition"],
    margins=True
)
# Out:
# attrition                 No  Yes   All
# department
# Human Resources           51   12    63
# Research & Development   828  133   961
# Sales                    354   92   446
# All                     1233  237  1470

# %%
# Marital status vs attrition
pd.crosstab(df_clean["marital_status"], df_clean["attrition"], normalize= "index")* 100
# Out:
# attrition              No        Yes
# marital_status
# Divorced        89.908257  10.091743
# Married         87.518574  12.481426
# Single          74.468085  25.531915

# %% [markdown]
# # Group by Analysis

# %%
# Employee count by department
df_clean.groupby("department").size()
# Out:
# department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
# Average salary by department
df_clean.groupby("department")["monthly_income"].mean().round(2).reset_index()
# Out:
#                department  monthly_income
# 0         Human Resources         6654.51
# 1  Research & Development         6281.25
# 2                   Sales         6959.17

# %%
# Average age
df_clean.groupby("department")["age"].mean().round(1).reset_index()
# Out:
#                department   age
# 0         Human Resources  37.8
# 1  Research & Development  37.0
# 2                   Sales  36.5

# %%
# Average Years at Company
df_clean.groupby("department")["years_at_company"].mean().round(1).reset_index()
# Out:
#                department  years_at_company
# 0         Human Resources               7.2
# 1  Research & Development               6.9
# 2                   Sales               7.3

# %%
# Average Total Working Years
df_clean.groupby("department")["total_working_years"].mean().round(1).reset_index()
# Out:
#                department  total_working_years
# 0         Human Resources                 11.6
# 1  Research & Development                 11.3
# 2                   Sales                 11.1

# %%
# Average Job satisfaction
df_clean.groupby("department")["job_satisfaction"].mean().round(2).reset_index()
# Out:
#                department  job_satisfaction
# 0         Human Resources              2.60
# 1  Research & Development              2.73
# 2                   Sales              2.75

# %%
# Average Work Life Balance
df_clean.groupby("department")["work_life_balance"].mean().round(2).reset_index()
# Out:
#                department  work_life_balance
# 0         Human Resources               2.92
# 1  Research & Development               2.73
# 2                   Sales               2.82

# %%
# Average Performance Rating
df_clean.groupby("department")["performance_rating"].mean().round(2).reset_index()
# Out:
#                department  performance_rating
# 0         Human Resources                3.14
# 1  Research & Development                3.16
# 2                   Sales                3.14

# %%
# Average Distance From Home
df_clean.groupby("department")["distance_from_home"].mean().round(2).reset_index()
# Out:
#                department  distance_from_home
# 0         Human Resources                8.70
# 1  Research & Development                9.14
# 2                   Sales                9.37

# %%
# Average Monthly Income by Job role
df_clean.groupby("job_role")["monthly_income"].mean().round(2).reset_index()
# Out:
#                     job_role  monthly_income
# 0  Healthcare Representative         7528.76
# 1            Human Resources         4235.75
# 2      Laboratory Technician         3237.17
# 3                    Manager        17181.68
# 4     Manufacturing Director         7295.14
# 5          Research Director        16033.55
# 6         Research Scientist         3239.97
# 7            Sales Executive         6924.28
# 8       Sales Representative         2626.00

# %%
# Average Age by Job Role
df_clean.groupby("job_role")["age"].mean().round(1).reset_index()
# Out:
#                     job_role   age
# 0  Healthcare Representative  39.8
# 1            Human Resources  35.5
# 2      Laboratory Technician  34.1
# 3                    Manager  46.8
# 4     Manufacturing Director  38.3
# 5          Research Director  44.0
# 6         Research Scientist  34.2
# 7            Sales Executive  36.9
# 8       Sales Representative  30.4

# %%
# Average Years Since Last Promotion
df_clean.groupby("job_role")["years_since_last_promotion"].mean().round(1).reset_index()
# Out:
#                     job_role  years_since_last_promotion
# 0  Healthcare Representative                         3.0
# 1            Human Resources                         1.3
# 2      Laboratory Technician                         1.4
# 3                    Manager                         4.8
# 4     Manufacturing Director                         2.1
# 5          Research Director                         3.2
# 6         Research Scientist                         1.5
# 7            Sales Executive                         2.5
# 8       Sales Representative                         1.1

# %%
# Attrition rate by department
(
    df_clean.groupby("department")["attrition"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)
# Out:
# department              attrition
# Human Resources         No           80.95
#                         Yes          19.05
# Research & Development  No           86.16
#                         Yes          13.84
# Sales                   No           79.37
#                         Yes          20.63
# Name: proportion, dtype: float64

# %% [markdown]
# # Top Employees

# %%
# Highest salary
df_clean.nlargest(10, "monthly_income")
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 190    52        No      Travel_Rarely         699  Research & Development
# 746    41        No         Non-Travel         247  Research & Development
# 851    56        No      Travel_Rarely         718  Research & Development
# 165    50        No      Travel_Rarely        1452  Research & Development
# 568    55       Yes      Travel_Rarely         725  Research & Development
# 918    51        No  Travel_Frequently         237                   Sales
# 749    52       Yes      Travel_Rarely         266                   Sales
# 1242   40        No      Travel_Rarely         611                   Sales
# 898    43        No      Travel_Rarely         920  Research & Development
# 956    56        No      Travel_Rarely         206         Human Resources
#
#       distance_from_home  education   education_field  employee_number  \
# ...

# %%
# oldest employees
df_clean.nlargest(10, "age")
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 411    60        No      Travel_Rarely         422  Research & Development
# 427    60        No  Travel_Frequently        1499                   Sales
# 536    60        No      Travel_Rarely        1179                   Sales
# 879    60        No      Travel_Rarely         696                   Sales
# 1209   60        No      Travel_Rarely         370  Research & Development
# 6      59        No      Travel_Rarely        1324  Research & Development
# 63     59        No      Travel_Rarely        1435                   Sales
# 70     59        No  Travel_Frequently        1225                   Sales
# 105    59        No         Non-Travel        1420         Human Resources
# 225    59        No      Travel_Rarely         142  Research & Development
#
#       distance_from_home  education  education_field  employee_number  \
# 411                    7          3    Life Sciences              549
# ...

# %%
# Most experienced
df_clean.nlargest(10, "total_working_years")
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 126    58       Yes      Travel_Rarely         147  Research & Development
# 595    58       Yes      Travel_Rarely         286  Research & Development
# 98     58        No      Travel_Rarely         682                   Sales
# 85     56        No      Travel_Rarely        1400  Research & Development
# 270    55        No      Travel_Rarely         452  Research & Development
# 445    55        No      Travel_Rarely        1117                   Sales
# 1301   58        No         Non-Travel         350                   Sales
# 187    55        No      Travel_Rarely         692  Research & Development
# 401    56        No  Travel_Frequently         906                   Sales
# 894    54        No      Travel_Rarely         685  Research & Development
#
#       distance_from_home  education education_field  employee_number  \
# 126                   23          4         Medical              165
# ...

# %%
# Save the data 
df_clean.to_csv("C:/Work/Projects/Project Python/hr_clean.csv", index=False)
